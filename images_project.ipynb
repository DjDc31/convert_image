# %%
from PIL import features

print(features.pilinfo())
# Out:
# --------------------------------------------------------------------
# Pillow 9.5.0
# Python 3.10.6 (main, Oct 10 2022, 13:03:01) [Clang 14.0.0 (clang-1400.0.29.102)]
# --------------------------------------------------------------------
# Python modules loaded from /Users/cyrille/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/PIL
# Binary modules loaded from /Users/cyrille/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/PIL
# --------------------------------------------------------------------
# --- PIL CORE support ok, compiled for 9.5.0
# --- TKINTER support ok, loaded 8.5
# --- FREETYPE2 support ok, loaded 2.13.0
# --- LITTLECMS2 support ok, loaded 2.15
# --- WEBP support ok, loaded 1.3.0
# --- WEBP Transparency support ok
# --- WEBPMUX support ok
# --- WEBP Animation support ok
# --- JPEG support ok, compiled for libjpeg-turbo 2.1.5.1
# --- OPENJPEG (JPEG2000) support ok, loaded 2.5.0
# --- ZLIB (PNG/ZIP) support ok, loaded 1.2.13
# ...
